# %%
import pandas as pd
import os

# %%
full_df = pd.read_csv(os.path.join('..', 'dataframe.csv'))
full_df.head()
# Out:
#                    timestamp  position_lat  position_long  distance  \
# 0  2024-02-29T16:05:27+00:00    -11.640456     166.994119       NaN
# 1  2024-02-29T16:05:28+00:00    -11.640510     166.994054       NaN
# 2  2024-02-29T16:05:29+00:00    -11.640566     166.993990       NaN
# 3  2024-02-29T16:05:30+00:00    -11.640625     166.993936       NaN
# 4  2024-02-29T16:05:31+00:00    -11.640685     166.993883       NaN
#
#    time_from_course    speed  compressed_speed_distance  heart_rate  \
# 0               NaN  34.2324                        NaN          85
# 1               NaN  33.8076                        NaN          85
# 2               NaN  33.3900                        NaN          85
# 3               NaN  32.9292                        NaN          86
# 4               NaN  32.5296                        NaN          86
#
#    enhanced_altitude  altitude  enhanced_speed  power  grade  cadence  \
# 0               13.2      13.2         34.2324     87    NaN       66
# ...

# %%
full_df.describe()
# Out:
#        position_lat  position_long  distance  time_from_course         speed  \
# count  14663.000000   14663.000000       0.0               0.0  14663.000000
# mean       1.930600     131.914304       NaN               NaN     27.231555
# std       26.732554      68.989173       NaN               NaN      8.512839
# min      -11.663637      -5.244547       NaN               NaN      0.000000
# 25%      -11.649099     166.937610       NaN               NaN     22.626000
# 50%      -11.642100     166.949100       NaN               NaN     28.731600
# 75%      -11.636711     166.982392       NaN               NaN     32.400000
# max       55.659018     167.002798       NaN               NaN     58.521600
#
#        compressed_speed_distance    heart_rate  enhanced_altitude  \
# count                        0.0  14663.000000       14663.000000
# mean                         NaN    158.236991          20.566351
# std                          NaN     16.730517          22.946025
# ...

# %%
columns_with_all_nan = full_df.columns[full_df.isna().all()]
print(columns_with_all_nan)
# Out:
# Index(['distance', 'time_from_course', 'compressed_speed_distance', 'grade',
#        'resistance', 'cycle_length', 'temperature'],
#       dtype='object')

# %%
full_df.groupby('training').mean()
# Out:
#                                           position_lat  position_long  \
# training
# .\data\json\2024-02-29-17-04-33.fit.json    -11.641780     166.992516
# .\data\json\2024-02-29-17-10-41.fit.json    -11.640313     166.984394
# .\data\json\2024-02-29-17-19-52.fit.json    -11.658161     166.985415
# .\data\json\2024-02-29-19-29-20.fit.json    -11.646042     166.951352
# .\data\json\2024-03-03-19-36-49.fit.json    -11.646398     166.988959
# .\data\json\2024-03-04-20-10-27.fit.json     55.647399      -5.233761
# .\data\json\2024-03-06-17-47-43.fit.json    -11.643968     166.941293
# .\data\json\2024-03-06-18-49-22.fit.json     51.504332      -0.133296
# .\data\json\2024-03-09-16-50-26.fit.json    -11.645545     166.969868
#
#                                           distance  time_from_course  \
# training
# .\data\json\2024-02-29-17-04-33.fit.json       NaN               NaN
# .\data\json\2024-02-29-17-10-41.fit.json       NaN               NaN
# ...
